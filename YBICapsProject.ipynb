# %% [markdown]
# YBI Foundation Internship Program
# https://ybif.ybifoundation.org/
#
# Dataset Information
# Dataset Link:
#
# https://www.kaggle.com/anandhuh/latest-covid19-india-statewise-data
#
# About::
#
#  Name: Shreyas Deodhare
#
#  Batch : 2 Feb 2022
#
#  Attribute Information
# 1. State/UTs - Names of Indian States and Union Territories.
# 2. Total Cases - Total number of confirmed cases
# 3. Active - Total number of active cases
# 4. Discharged - Total number of discharged cases
# 5. Deaths - Total number of deaths
# 6. Active Ratio (%) - Ratio of number of active cases to total cases
# 7. Discharge Ratio (%) - Ratio of number of discharged cases to total cases
# 8. Death Ratio (%) - Ratio of number of deaths to total cases
# 9. Population - Population of State/UT

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('covid.csv')

# %%
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman And Nicobar        10032       1        9902
# 1                             Andhra Pradesh      2319504     346     2304428
# 2                          Arunachal Pradesh        64484       0       64188
# 3                                      Assam       724196    1358      716199
# 4                                      Bihar       830459      32      818171
# 5                                 Chandigarh        91911      19       90727
# 6                               Chhattisgarh      1152084     147     1137903
# 7   Dadra And Nagar Haveli And Daman And Diu        11441       0       11437
# 8                                      Delhi      1864639     444     1838044
# 9                                        Goa       245280      29      241421
# 10                                   Gujarat      1223879     234     1212703
# 11                                   Haryana       985066     329      974125
# 12                          Himachal Pradesh       284491     171      280187
# 13                         Jammu And Kashmir       453677     146      448781
# 14                                 Jharkhand       435130      64      429751
# 15                                 Karnataka      3945359    1761     3903547
# 16                                    Kerala      6531392    4513     6459057
# 17                                    Ladakh        28220      15       27977
# 18                               Lakshadweep        11402       0       11350
# 19                            Madhya Pradesh      1041065     158     1030173
# 20                               Maharashtra      7873619     964     7724875
# 21                                   Manipur       137086      37      134929
# 22                                 Meghalaya        93759      38       92128
# 23                                   Mizoram       224104    1162      222258
# 24                                  Nagaland        35470      16       34696
# 25                                    Odisha      1287512     472     1277921
# 26                                Puducherry       165774       2      163810
# 27                                    Punjab       759067     130      741196
# 28                                 Rajasthan      1282920     264     1273105
# 29                                    Sikkim        39138      17       38669
# 30                                Tamil Nadu      3452714     366     3414323
# 31                                 Telengana       791181     492      786578
# 32                                   Tripura       100873       3       99951
# 33                             Uttar Pradesh      2070600     467     2046639
# 34                               Uttarakhand       437221     501      429029
# 35                               West Bengal      2017233     680     1995356
#
#     Deaths  Active Ratio  Discharge Ratio  Death Ratio  Population
# 0      129          0.01            98.70         1.29   100896618
# 1    14730          0.01            99.35         0.64   128500364
# 2      296          0.00            99.54         0.46      658019
# 3     6639          0.19            98.90         0.92      290492
# 4    12256          0.00            98.52         1.48    40100376
# 5     1165          0.02            98.71         1.27    79502477
# 6    14034          0.01            98.77         1.22    28900667
# 7        4          0.00            99.97         0.03   231502578
# 8    26151          0.02            98.57         1.40      773997
# 9     3830          0.01            98.43         1.56     3772103
# 10   10942          0.02            99.09         0.89    70400153
# 11   10612          0.03            98.89         1.08    14999397
# 12    4133          0.06            98.49         1.45     3436948
# 13    4750          0.03            98.92         1.05       66001
# 14    5315          0.01            98.76         1.22   124904071
# 15   40051          0.04            98.94         1.02     1711947
# 16   67822          0.07            98.89         1.04    91702478
# 17     228          0.05            99.14         0.81     4184959
# 18      52          0.00            99.54         0.46    11700099
# 19   10734          0.02            98.95         1.03     7503010
# 20  147780          0.01            98.11         1.88      399001
# 21    2120          0.03            98.43         1.55    47099270
# 22    1593          0.04            98.26         1.70    30501026
# 23     684          0.52            99.18         0.31     1308967
# 24     758          0.05            97.82         2.14    38157311
# 25    9119          0.04            99.26         0.71    19301096
# 26    1962          0.00            98.82         1.18     2073074
# 27   17741          0.02            97.65         2.34    34698876
# 28    9551          0.02            99.23         0.74     1521992
# 29     452          0.04            98.80         1.15    83697770
# 30   38025          0.01            98.89         1.10    35998752
# 31    4111          0.06            99.42         0.52    69599762
# 32     919          0.00            99.09         0.91     1646050
# 33   23494          0.02            98.84         1.13     1158040
# 34    7691          0.11            98.13         1.76    85002417
# 35   21197          0.03            98.92         1.05    32199722

# %%
df.shape
# Out:
# (36, 9)

# %%
df.head()
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman And Nicobar        10032       1        9902     129          0.01
# 1       Andhra Pradesh      2319504     346     2304428   14730          0.01
# 2    Arunachal Pradesh        64484       0       64188     296          0.00
# 3                Assam       724196    1358      716199    6639          0.19
# 4                Bihar       830459      32      818171   12256          0.00
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.70         1.29   100896618
# 1            99.35         0.64   128500364
# 2            99.54         0.46      658019
# 3            98.90         0.92      290492
# 4            98.52         1.48    40100376

# %%
df.tail()
# Out:
#         State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 31      Telengana       791181     492      786578    4111          0.06
# 32        Tripura       100873       3       99951     919          0.00
# 33  Uttar Pradesh      2070600     467     2046639   23494          0.02
# 34    Uttarakhand       437221     501      429029    7691          0.11
# 35    West Bengal      2017233     680     1995356   21197          0.03
#
#     Discharge Ratio  Death Ratio  Population
# 31            99.42         0.52    69599762
# 32            99.09         0.91     1646050
# 33            98.84         1.13     1158040
# 34            98.13         1.76    85002417
# 35            98.92         1.05    32199722

# %%
df.describe()
# Out:
#         Total Cases       Active    Discharged         Deaths  Active Ratio  \
# count  3.600000e+01    36.000000  3.600000e+01      36.000000     36.000000
# mean   1.195055e+06   427.166667  1.180154e+06   14474.166667      0.044444
# std    1.767958e+06   814.630731  1.742116e+06   26859.333803      0.089137
# min    1.003200e+04     0.000000  9.902000e+03       4.000000      0.000000
# 25%    9.909450e+04    18.500000  9.799525e+04    1103.500000      0.010000
# 50%    5.889365e+05   152.500000  5.824900e+05    5977.000000      0.020000
# 75%    1.284068e+06   468.250000  1.274309e+06   14208.000000      0.040000
# max    7.873619e+06  4513.000000  7.724875e+06  147780.000000      0.520000
#
#        Discharge Ratio  Death Ratio    Population
# count        36.000000    36.000000  3.600000e+01
# mean         98.831111     1.124722  3.971861e+07
# std           0.480159     0.493115  5.050913e+07
# min          97.650000     0.030000  6.600100e+04
# 25%          98.557500     0.870000  1.695473e+06
# 50%          98.890000     1.090000  2.410088e+07
# 75%          99.102500     1.412500  6.979986e+07
# max          99.970000     2.340000  2.315026e+08

# %%
df.columns
# Out:
# Index(['State/UTs', 'Total Cases', 'Active', 'Discharged', 'Deaths',
#        'Active Ratio', 'Discharge Ratio', 'Death Ratio', 'Population'],
#       dtype='object')

# %%
df.corr()
# Out:
#                  Total Cases    Active  Discharged    Deaths  Active Ratio  \
# Total Cases         1.000000  0.692350    0.999988  0.941923     -0.079945
# Active              0.692350  1.000000    0.694309  0.508688      0.303726
# Discharged          0.999988  0.694309    1.000000  0.940240     -0.079809
# Deaths              0.941923  0.508688    0.940240  1.000000     -0.095007
# Active Ratio       -0.079945  0.303726   -0.079809 -0.095007      1.000000
# Discharge Ratio    -0.113268  0.034457   -0.111085 -0.251606      0.046811
# Death Ratio         0.123524 -0.087393    0.121369  0.261255     -0.221822
# Population         -0.065772  0.016033   -0.064911 -0.119617     -0.153326
#
#                  Discharge Ratio  Death Ratio  Population
# Total Cases            -0.113268     0.123524   -0.065772
# Active                  0.034457    -0.087393    0.016033
# Discharged             -0.111085     0.121369   -0.064911
# Deaths                 -0.251606     0.261255   -0.119617
# Active Ratio            0.046811    -0.221822   -0.153326
# Discharge Ratio         1.000000    -0.984349    0.229127
# Death Ratio            -0.984349     1.000000   -0.196664
# Population              0.229127    -0.196664    1.000000

# %%
y=df[['Deaths']]

# %%
X=df[['Total Cases']]

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()

# %%
X=ss.fit_transform(X)

# %%
df.describe()
# Out:
#         Total Cases       Active    Discharged         Deaths  Active Ratio  \
# count  3.600000e+01    36.000000  3.600000e+01      36.000000     36.000000
# mean   1.195055e+06   427.166667  1.180154e+06   14474.166667      0.044444
# std    1.767958e+06   814.630731  1.742116e+06   26859.333803      0.089137
# min    1.003200e+04     0.000000  9.902000e+03       4.000000      0.000000
# 25%    9.909450e+04    18.500000  9.799525e+04    1103.500000      0.010000
# 50%    5.889365e+05   152.500000  5.824900e+05    5977.000000      0.020000
# 75%    1.284068e+06   468.250000  1.274309e+06   14208.000000      0.040000
# max    7.873619e+06  4513.000000  7.724875e+06  147780.000000      0.520000
#
#        Discharge Ratio  Death Ratio    Population
# count        36.000000    36.000000  3.600000e+01
# mean         98.831111     1.124722  3.971861e+07
# std           0.480159     0.493115  5.050913e+07
# min          97.650000     0.030000  6.600100e+04
# 25%          98.557500     0.870000  1.695473e+06
# 50%          98.890000     1.090000  2.410088e+07
# 75%          99.102500     1.412500  6.979986e+07
# max          99.970000     2.340000  2.315026e+08

# %%
from matplotlib import pyplot as plt

# %%
sns.scatterplot(x="Total Cases",y="Deaths",data=df,hue='Active')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=27)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
y_test.head()
# Out:
#     Deaths
# 9     3830
# 22    1593
# 33   23494
# 16   67822
# 18      52

# %%
y_pred[0:5]
# Out:
# array([[  -699.4547842 ],
#        [ -3240.80786849],
#        [ 29915.32872313],
#        [104732.9943112 ],
#        [ -4622.12277509]])

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,mean_absolute_percentage_error,r2_score

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 161963479.4111723

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 8343.156884776941

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 9.465825922202365

# %%
r2_score(y_test,y_pred)
# Out:
# 0.605525841096524

# %%
y=df['Deaths']

# %%
X=df[[ 'Active','Total Cases']]

# %%
sns.pairplot(df,x_vars=['Active','Total Cases'],y_vars='Deaths')

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=27)

# %%
lr2=LinearRegression()

# %%
lr2.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr2.predict(X_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 47975163.60635783

# %%
y_test.head()
# Out:
#     Deaths
# 9     3830
# 22    1593
# 33   23494
# 16   67822
# 18      52

# %%
y_pred[0:5]
# Out:
# array([[ 1093.97673656],
#        [-1752.32827567],
#        [30285.95286746],
#        [73873.11581385],
#        [-2899.34348209]])

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 5169.038684985056

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 6.036552185349077

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8831529034775156
